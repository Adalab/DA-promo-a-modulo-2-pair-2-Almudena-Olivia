# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("forbes_2022_billionaires.csv")
df.sample()

# %%
pd.options.display.max_columns = None
df.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category              source        country       state  \
# 0             Automotive       Tesla, SpaceX  United States       Texas
# 1             Technology              Amazon  United States  Washington
# 2       Fashion & Retail                LVMH         France         NaN
# 3             Technology           Microsoft  United States  Washington
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska
#
#       city countryOfCitizenship                      organization  selfMade  \
# 0   Austin        United States                             Tesla      True
# 1  Seattle        United States                            Amazon      True
# 2    Paris               France  LVMH Moët Hennessy Louis Vuitton     False
# 3   Medina        United States   Bill & Melinda Gates Foundation      True
# 4    Omaha        United States                Berkshire Hathaway      True
#
#   gender   birthDate             title  philanthropyScore  \
# 0      M  1971-06-28               CEO                1.0
# 1      M  1964-01-12      Entrepreneur                1.0
# 2      M  1949-03-05  Chairman and CEO                NaN
# 3      M  1955-10-28         Cofounder                4.0
# 4      M  1930-08-30               CEO                5.0
#
#                   residenceMsa  numberOfSiblings  \
# 0                          NaN               NaN
# 1  Seattle-Tacoma-Bellevue, WA               NaN
# 2                          NaN               NaN
# 3  Seattle-Tacoma-Bellevue, WA               NaN
# 4                    Omaha, NE               NaN
#
#                                                  bio  \
# 0  Elon Musk is working to revolutionize transpor...
# 1  Jeff Bezos founded e-commerce giant Amazon in ...
# 2  Bernard Arnault oversees the LVMH empire of so...
# 3  Bill Gates turned his fortune from software fi...
# 4  Known as the "Oracle of Omaha," Warren Buffett...
#
#                                                about  50.0  58.0  73.0  66.0  \
# 0  Musk was accepted to a graduate program at Sta...  19.0  19.0  19.0  19.0
# 1  Growing up, Jeff Bezos worked summers on his g...  19.0  19.0  19.0  19.0
# 2  Arnault apparently wooed his wife, Helene Merc...  19.0  19.0  19.0  19.0
# 3  When Gates was a kid, he spent so much time re...  19.0  19.0  19.0  19.0
# 4  Buffett still lives in the same Omaha, Nebrask...  19.0  19.0  19.0  19.0
#
#    91.0  49.0  48.0  77.0  64.0  59.0  80.0  82.0  68.0  37.0  67.0  72.0  \
# 0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 1  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 2  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 3  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 4  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
#
#    44.0  86.0  57.0  38.0  84.0  53.0  51.0  52.0  85.0   NaN  93.0  75.0  \
# 0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 1  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 2  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 3  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 4  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
#
#    94.0  71.0  76.0  83.0  79.0  56.0  30.0  81.0  89.0  40.0  60.0  55.0  \
# 0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 1  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 2  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 3  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 4  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
#
#    65.0  54.0  74.0  61.0  63.0  35.0  69.0  42.0  92.0  70.0  98.0  62.0  \
# 0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 1  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 2  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 3  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 4  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
#
#    43.0  46.0  31.0  33.0  78.0  88.0  90.0  41.0  36.0  87.0  39.0  34.0  \
# 0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 1  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 2  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 3  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
# 4  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0
#
#    95.0  45.0  28.0  47.0  97.0  96.0  32.0  19.0  27.0  100.0  26.0  25.0  \
# 0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0   19.0  19.0  19.0
# 1  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0   19.0  19.0  19.0
# 2  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0   19.0  19.0  19.0
# 3  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0   19.0  19.0  19.0
# 4  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0   19.0  19.0  19.0
#
#    29.0
# 0  19.0
# 1  19.0
# 2  19.0
# 3  19.0
# 4  19.0

# %%
df.shape
# Out:
# (2668, 99)

# %% [markdown]
# EJERCICIO 1:
# Extraer las siguentes estadísiticas del conjunto de datos para varias de las varibles disponibles:

# %% [markdown]
# - Utilizando métodos de pandas: media, mediana, moda, máximo y mínimo

# %%
age = df['age']

# %%
edades_bien = df.copy()

# %%
edades_bien.dropna(subset = ["age"], inplace=True)

# %%
age_bien = edades_bien['age']

# %%
media = np.mean(age_bien)
print('La media de edad es de:', media)
# Out:
# La media de edad es de: 64.21068938807126

# %%
mediana = np.median(age_bien)
print('La mediana es:', mediana)
# Out:
# La mediana es: 64.0

# %%
moda, frecuencia = stats.mode(age_bien)
print('La moda de edad es:', moda,'y la frecuencia es:', frecuencia)
# Out:
# La moda de edad es: [57.] y la frecuencia es: [82]

# %%
minimo = np.min(age_bien)
print('La edad mínima es:', minimo)
# Out:
# La edad mínima es: 19.0

# %%
maximo = np.max(age_bien)
print('La edad máxima es:', maximo)
# Out:
# La edad máxima es: 100.0

# %% [markdown]
# - Percentiles 25, 75

# %%
q3, q1 = np.percentile(age_bien, [75, 25])
print('El percentil 25 es:', q1)
print('El percentil 75 es:', q3)
# Out:
# El percentil 25 es: 55.0
# El percentil 75 es: 74.0

# %% [markdown]
# - Rango Intercualtílico

# %%
riq = q3 - q1
print("El rango intercuartílico es:", riq)
# Out:
# El rango intercuartílico es: nan

# %% [markdown]
# - Boxplot de algunas variables

# %%
patrimonio = edades_bien['finalWorth']
ranking = edades_bien['rank']

# %%
datos_graf = [age_bien,ranking]
fig = plt.figure(1, figsize=(6,10))
ax = fig.add_subplot(111)
boxplot = ax.boxplot(datos_graf)
for flier in boxplot['fliers']:
    flier.set(marker='o', color='red', alpha=0.5)

# %% [markdown]
# - Tabla de frecuencias
#     - Variables cualitativas
#     - Variables cuantitativas
#     - Frecuencia acumulada
#     - Representación de al menos una tabla de frecuencias

# %% [markdown]
#     - variable cualitativa

# %%
edades_categoria = edades_bien.groupby("category") 
print(edades_categoria)

frecuencias_categoria = edades_categoria.agg(frecuencia=("category", "count")) 
print(frecuencias_categoria)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f9ac3286520>
#                             frecuencia
# category
# Automotive                          67
# Construction & Engineering          45
# Diversified                        175
# Energy                              93
# Fashion & Retail                   242
# Finance & Investments              383
# Food & Beverage                    194
# Gambling & Casinos                  23
# Healthcare                         209
# Logistics                           33
# Manufacturing                      321
# Media & Entertainment               95
# Metals & Mining                     65
# Real Estate                        188
# Service                             52
# Sports                              27
# Technology                         333
# Telecom                             37

# %% [markdown]
#     - variable cuantitativa

# %%
edad_cuant = edades_bien.groupby("age")
frec_edad =  edad_cuant.agg(frecuencia=("age", "count"))
print(frec_edad)
# Out:
#        frecuencia
# age
# 19.0            1
# 25.0            3
# 26.0            2
# 27.0            2
# 28.0            2
# ...           ...
# 95.0            7
# 96.0            5
# 97.0            3
# 98.0            3
# 100.0           1
#
# [76 rows x 1 columns]

# %% [markdown]
#     - frecuencia acumulada

# %%
bins = np.arange(19, 100+10, 10)

edades_bien["age_group"] = pd.cut(edades_bien["age"], bins=bins)

edades_cut = edades_bien.groupby("age_group")
edades_cut_bins =  edades_cut.agg(frecuencia=("age", "count"))
edades_cut_bins["frecuencia_acumulada_edad"] = edades_cut_bins["frecuencia"].cumsum()
edades_cut_bins
# Out:
#            frecuencia  frecuencia_acumulada_edad
# age_group
# (19, 29]           11                         11
# (29, 39]           75                         86
# (39, 49]          243                        329
# (49, 59]          678                       1007
# (59, 69]          658                       1665
# (69, 79]          562                       2227
# (79, 89]          282                       2509
# (89, 99]           71                       2580
# (99, 109]           1                       2581

# %% [markdown]
#     - Representación de al menos una tabla de frecuencias

# %%
plt.rcdefaults()

df_categoria = edades_bien.groupby("category") 
frecuencias_categoria = df_categoria.agg(frecuencia=("category", "count")) 
frecuencias_categoria.plot.bar()
# Out:
# <AxesSubplot:xlabel='category'>

# %% [markdown]
# EJERCICIO 2: Interpretación de los resultados.

# %% [markdown]
# Gracias a la gráfica podemos ver en qué sectores han hecho su fortuna estas personas, siendo la más habitual el sector de finanzas
# e inversiones, seguido del sector tecnológico y la manufacturación.
