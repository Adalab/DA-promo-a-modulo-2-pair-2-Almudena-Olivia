# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# EJERCICIO 1:Buscar un conjunto de datos a analizar:

# %%
df = pd.read_csv("forbes_2022_billionaires.csv")
df.head(30)
# Out:
#     rank                             personName   age  finalWorth  year  \
# 0      1                              Elon Musk  50.0    219000.0  2022
# 1      2                             Jeff Bezos  58.0    171000.0  2022
# 2      3               Bernard Arnault & family  73.0    158000.0  2022
# 3      4                             Bill Gates  66.0    129000.0  2022
# 4      5                         Warren Buffett  91.0    118000.0  2022
# 5      6                             Larry Page  49.0    111000.0  2022
# 6      7                            Sergey Brin  48.0    107000.0  2022
# 7      8                          Larry Ellison  77.0    106000.0  2022
# 8      9                          Steve Ballmer  66.0     91400.0  2022
# 9     10                          Mukesh Ambani  64.0     90700.0  2022
# 10    11                  Gautam Adani & family  59.0     90000.0  2022
# 11    12                      Michael Bloomberg  80.0     82000.0  2022
# ...

# %%
pd.options.display.max_columns = None

# %%
df.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category              source        country       state  \
# 0             Automotive       Tesla, SpaceX  United States       Texas
# 1             Technology              Amazon  United States  Washington
# 2       Fashion & Retail                LVMH         France         NaN
# 3             Technology           Microsoft  United States  Washington
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska
#
#       city countryOfCitizenship                      organization  selfMade  \
# ...

# %% [markdown]
# EJERCICIO 2: Extraer las siguentes estadísiticas del conjunto de datos para varaias de las varibles disponibles:

# %%
finalWorth = df['finalWorth']

# %%
media = np.mean(finalWorth)
print('La media de patrimonio es de:', media)
# Out:
# La media de patrimonio es de: 4762.350074962519

# %%
desviacion_media = np.abs(finalWorth-media)
print('La desviacion media de patrimonion es de:', '\n', desviacion_media)
# Out:
# La desviacion media de patrimonion es de:
#  0       214237.649925
# 1       166237.649925
# 2       153237.649925
# 3       124237.649925
# 4       113237.649925
#             ...
# 2663      3762.350075
# 2664      3762.350075
# 2665      3762.350075
# 2666      3762.350075
# 2667      3762.350075
# Name: finalWorth, Length: 2668, dtype: float64

# %%
varianza = np.var(finalWorth)
print('La varianza de los datos del patrimonio es de:', varianza)
# Out:
# La varianza de los datos del patrimonio es de: 111060123.89993542

# %%
desviacion_tipica = np.std(finalWorth)
print('La desviación típica es de:', desviacion_tipica)
# Out:
# La desviación típica es de: 10538.506720590703

# %%
moda, frecuencia = stats.mode(finalWorth)
print('La moda del patrimonio es:', moda,'y la frecuencia es:', frecuencia)
# Out:
# La moda del patrimonio es: [1500.] y la frecuencia es: [147]

# %%
mediana = np.median(finalWorth)
print('La mediana es:', mediana)
# Out:
# La mediana es: 2400.0

# %%
finalWorth.shape
# Out:
# (2668,)

# %%
w = np.ones(2668, dtype=np.complex64)
avg = np.average(finalWorth, weights=w)
print('La media ponderada es:', avg)
# Out:
# La media ponderada es: (4762.350074962518+0j)

# %% [markdown]
# Robustez: La media no es robusta porque hay mucha diferencia entre los valores. Serán más robustas la media y la moda ya que se repiten 147 valores y la mediana no se verá afectada en caso de que se añada un nuevo elemento muy diferente en comparación a los qu eya están.

# %%
coeficiente_variacion = desviacion_tipica/ media
print('El coeficiente de variación es:', coeficiente_variacion)
print('Los datos no son robustos porque el coeficiente de variación es muy alto')
# Out:
# El coeficiente de variación es: 2.2128794722579577
# Los datos no son robustos porque el coeficiente de variación es muy alto

# %%
plt.figure()
fig = sns.scatterplot(x='rank' , y='finalWorth' , data = df)
fig.set(xlabel='Posición', ylabel = 'Patrimonio')
fig.set_title('Patrimonio total.')
plt.show()

# %%
plt.figure()
fig = sns.barplot(x='gender' , y='rank' , data = df)
fig.set(xlabel='Género', ylabel = 'Patrimonio')
fig.set_title('Comparación de patrimonio total entre hombres y mujeres.')
plt.show()

# %%
plt.figure()
fig = sns.barplot(x='selfMade' , y='rank' , data = df)
fig.set(xlabel='Conseguido por sus medios', ylabel = 'Ranking')
fig.set_title('Diferencia entre los que han conseguido su patrimonio por sus medios y los que han heredado y su posición en el ranking.')
plt.show()
